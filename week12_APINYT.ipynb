# %% [markdown]
# ## Archive API from the New York Times

# %%
#Importing the libraries
import requests
import json
import pandas as pd
from pandas import DataFrame

# %%
#Calling the API
your_key = '0kl0DnG688Ec6mw3hjQjrGFz00LiyMHG'
url = 'https://api.nytimes.com/svc/topstories/v2/science.json?api-key='+ your_key
r = requests.get(url)
json_data = r.json()

# %%
#Opening the .json File
json_data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.',
#  'section': 'science',
#  'last_updated': '2019-11-17T21:47:08-05:00',
#  'num_results': 39,
#  'results': [{'section': 'Science',
#    'subsection': '',
#    'title': 'Millions of Ibises Were Mummified. But Where Did Ancient Egypt Get Them?',
#    'abstract': 'DNA analysis of the preserved birds found in many catacombs undercuts the explanation that there were large-scale ibis breeding farms.',
#    'url': 'https://www.nytimes.com/2019/11/16/science/mummies-ibises-ancient-egypt.html',
#    'byline': 'By CARA GIAIMO',
#    'item_type': 'Article',
#    'updated_date': '2019-11-16T05:00:12-05:00',
#    'created_date': '2019-11-16T05:00:12-05:00',
#    'published_date': '2019-11-16T05:00:12-05:00',
#    'material_type_facet': '',
#    'kicker': '',
#    'des_facet': ['Birds',
#     'Egyptian Civilization',
#     'Archaeology and Anthropology',
#     'Mummies and Mummification',
# ...

# %%
#Creating the dataframe
df = DataFrame(json_data)
s = pd.Series(df['results'])

list_df = pd.DataFrame([ pd.Series(value) for value in s ])
list_df
# Out:
#        section      subsection  \
# 0      Science
# 1      Science
# 2      Science
# 3      Science
# 4      Science
# 5      Science
# 6      Science
# 7      Science
# 8      Science
# 9         U.S.
# 10      Health
# 11       World          Europe
# 12      Health
# 13     Science
# 14     Science
# 15       World          Europe
# 16  Technology
# 17       World    Asia Pacific
# 18     Climate
# 19      Health
# 20     Climate
# 21     Science
# 22      Health
# 23        U.S.
# 24    New York
# 25     Science
# 26        Arts    Art & Design
# 27     Science  Space & Cosmos
# 28      Travel
# 29     Climate
# 30     Climate
# 31     Science
# 32       Books     Book Review
# 33        Arts    Art & Design
# 34     Climate
# 35     Science
# 36      Health
# 37     Science
# 38     Science
#
#                                                 title  \
# 0   Millions of Ibises Were Mummified. But Where D...
# 1      Leonids Meteor Shower Will Peak in Night Skies
# ...
